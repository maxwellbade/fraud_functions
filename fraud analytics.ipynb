# %%
#import libraries
import pandas as pd
import plotly
import numpy as np
import seaborn as sns
import os
import random

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.figure_factory as ff

# %%
#import dataset and show a few rows
df = pd.read_csv('creditcard.csv')
df.head(20).style.background_gradient(cmap="Blues")
# Out:
# <style  type="text/css" >
#     #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col1 {
#             background-color:  #4e9acb;
#             color:  #000000;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col2 {
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col4 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col5 {
#             background-color:  #aed1e7;
#             color:  #000000;
#         }    #T_fae5b0c2_c761_11ea_8c2e_6c40088c216arow0_col6 {
#             background-color:  #92c4de;
#             color:  #000000;
# ...

# %%
#create fraud column - keep class column
df['fraud'] = df['Class']
df.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col2 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col5 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_fe1a21b0_c761_11ea_81c8_6c40088c216arow0_col6 {
#             background-color:  #d9f0d3;
#             color:  #000000;
# ...

# %%
df.fraud.value_counts()
# Out:
# 0    284315
# 1       492
# Name: fraud, dtype: int64

# %%
#replace 0/1 with fraud/nonfraud in fraud col
# df['fraud'] = df[df['fraud'] == 1] = 'fraud'
# df['fraud'] = df[df['fraud'] == 0] = 'nonfraud'

df['fraud'].replace(0, 'nonfraud',inplace=True)
df['fraud'].replace(1, 'fraud',inplace=True)

df.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col1 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col2 {
#             background-color:  #83cb82;
#             color:  #000000;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col3 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col4 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col5 {
#             background-color:  #f0f9ec;
#             color:  #000000;
#         }    #T_2ea6d4fa_c397_11ea_b297_6c40088c216arow0_col6 {
#             background-color:  #d9f0d3;
#             color:  #000000;
# ...

# %%
#prove it worked
df.fraud.value_counts()
# Out:
# nonfraud    284315
# fraud          492
# Name: fraud, dtype: int64

# %%
#create makeshift accountid/id column for aggregator in fraud_rate function
randomlist = []
for i in range(len(df)):
    n = random.randint(1,10000)
    randomlist.append(n)

print(len(randomlist))
print(randomlist)
# Out:
# 284807
# ...

# %%
#create accountid column from randomlist and show head
df['accountid'] = randomlist
df.head(20).style.bar(color='teal')
# Out:
# <style  type="text/css" >
#     #T_0fdccfc6_c762_11ea_8486_6c40088c216arow0_col0 {
#             width:  10em;
#              height:  80%;
#         }    #T_0fdccfc6_c762_11ea_8486_6c40088c216arow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,teal 58.6%, transparent 58.6%);
#         }    #T_0fdccfc6_c762_11ea_8486_6c40088c216arow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,teal 78.3%, transparent 78.3%);
#         }    #T_0fdccfc6_c762_11ea_8486_6c40088c216arow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,teal 100.0%, transparent 100.0%);
#         }    #T_0fdccfc6_c762_11ea_8486_6c40088c216arow0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,teal 68.1%, transparent 68.1%);
# ...

# %%
#describe dataset
print(df.shape)
print(df.dtypes)
print(df.describe)
# Out:
# (284807, 33)
# Time         float64
# V1           float64
# V2           float64
# V3           float64
# V4           float64
# V5           float64
# V6           float64
# V7           float64
# V8           float64
# V9           float64
# V10          float64
# V11          float64
# V12          float64
# V13          float64
# V14          float64
# V15          float64
# V16          float64
# V17          float64
# V18          float64
# V19          float64
# V20          float64
# V21          float64
# V22          float64
# V23          float64
# V24          float64
# V25          float64
# V26          float64
# V27          float64
# V28          float64
# Amount       float64
# Class          int64
# fraud          int64
# accountid      int64
# dtype: object
# <bound method NDFrame.describe of             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# ...

# %%
def fraud_rate(df, agg, cols=None, threshold=None, limit=None, days=None):
    if isinstance(cols, str):
        groupcols = [cols]
    elif cols is None:
       groupcols = []
    else:
        try:
            groupcols = list(cols)
        except:
            raise TypeError('Unable to convert cols to a list. Figure out your shit')
    fraudcols = groupcols + ['fraud']
    cnts = df.groupby(fraudcols)[agg].nunique()
    if groupcols:
        wide = cnts.unstack('fraud').fillna(0)
    else:
        wide = cnts.to_frame().stack(level=0).unstack('fraud').fillna(0)
    wide = wide.assign(fraud_rate = wide.fraud / (wide.fraud + wide.nonfraud))
    if threshold:
        wide = wide.loc[wide.nonfraud.gt(threshold)]
    wide = wide.sort_values('fraud_rate', ascending=False)
    if limit:
        wide = wide.head(n=limit)
    wide = wide.assign(fpr=wide.nonfraud / wide.fraud)
    if days:
        wide = wide.assign(impact = (wide.nonfraud + wide.fraud) / days)
    return wide

# %%
#make columns list
test_cols = [V1,V2,V3]
test_cols
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-801419138168> in <module>
#       1 #make columns list
# ----> 2 test_cols = [V1,V2,V3]
#       3 test_cols
#
# NameError: name 'V1' is not defined

# %%
fraud_rate(df, 'accountid', test_cols)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-3cfbceefd4b5> in <module>
# ----> 1 fraud_rate(df, 'accountid', test_cols)
#
# <ipython-input-22-dfbda786b023> in fraud_rate(df, agg, cols, threshold, limit, days)
#      12     cnts = df.groupby(fraudcols)[agg].nunique()
#      13     if groupcols:
# ---> 14         wide = cnts.unstack('fraud').fillna(0)
#      15     else:
#      16         wide = cnts.to_frame().stack(level=0).unstack('fraud').fillna(0)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3548         from pandas.core.reshape.reshape import unstack
#    3549
# -> 3550         return unstack(self, level, fill_value)
#    3551
#    3552     # ----------------------------------------------------------------------
#
# ...

# %%
df.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
del df['Class']
